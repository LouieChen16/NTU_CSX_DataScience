# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tokenize import TreebankWordTokenizer
from nltk.tag import pos_tag
from nltk import ne_chunk, Tree
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Louie
# [nltk_data]     Chen\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Louie Chen\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to C:\Users\Louie
# [nltk_data]     Chen\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to C:\Users\Louie
# [nltk_data]     Chen\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
f = open('./Tesla.txt','r')
ex = f.readlines()
f.close()
len(ex)
# Out:
# 28

# %%
strEx = " ".join(str(x) for x in ex)

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
sent = preprocess(strEx)
sent
# Out:
# [('New', 'NNP'),
#  ('York', 'NNP'),
#  ('(', '('),
#  ('CNN', 'NNP'),
#  ('Business', 'NNP'),
#  (')', ')'),
#  ('Over', 'IN'),
#  ('the', 'DT'),
#  ('last', 'JJ'),
#  ('10', 'CD'),
#  ('years', 'NNS'),
#  ('Tesla', 'NNP'),
#  ('CEO', 'NNP'),
#  ('Elon', 'NNP'),
#  ('Musk', 'NNP'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('promising', 'VBG'),
#  ('Wall', 'NNP'),
#  ('Street', 'NNP'),
#  ('that', 'IN'),
#  ('his', 'PRP$'),
#  ('electric', 'JJ'),
#  ('car', 'NN'),
#  ('company', 'NN'),
#  ('would', 'MD'),
#  ('eventually', 'RB'),
#  ('make', 'VB'),
#  ('money', 'NN'),
#  ('.', '.'),
#  ('Wednesday', 'NNP'),
#  ('he', 'PRP'),
#  ('finally', 'RB'),
#  ('made', 'VBD'),
#  ('good', 'JJ'),
#  ('on', 'IN'),
#  ('that', 'DT'),
#  ('promise', 'NN'),
#  ('.', '.'),
#  ('Shares', 'NNS'),
#  ('closed', 'VBD'),
#  ('up', 'RB'),
#  ('9', 'CD'),
#  ('%', 'NN'),
#  ('Thursday', 'NNP'),
#  ('after', 'IN'),
#  ('the', 'DT'),
#  ('company', 'NN'),
#  ('posted', 'VBD'),
#  ('its', 'PRP$'),
#  ('best', 'JJS'),
#  ('quarter', 'NN'),
#  ('ever', 'RB'),
#  ('the', 'DT'),
#  ('previous', 'JJ'),
#  ('evening', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('big', 'JJ'),
#  ('question', 'NN'),
#  ('now', 'RB'),
#  ('is', 'VBZ'),
#  ('whether', 'IN'),
#  ('the', 'DT'),
#  ('company', 'NN'),
#  ('can', 'MD'),
#  ('remain', 'VB'),
#  ('profitable', 'JJ'),
#  ('.', '.'),
#  ('Tesla', 'NNP'),
#  ('scores', 'VBZ'),
#  ('a', 'DT'),
#  ('profit', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('Elon', 'NNP'),
#  ('Musk', 'NNP'),
#  ('keeps', 'VBZ'),
#  ('a', 'DT'),
#  ('promise', 'NN'),
#  ('Tesla', 'NNP'),
#  ('scores', 'VBZ'),
#  ('a', 'DT'),
#  ('profit', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('Elon', 'NNP'),
#  ('Musk', 'NNP'),
#  ('keeps', 'VBZ'),
#  ('a', 'DT'),
#  ('promise', 'NN'),
#  ('Tesla', 'NNP'),
#  ("'s", 'POS'),
#  ('strong', 'JJ'),
#  ('report', 'NN'),
#  ('showed', 'VBD'),
#  ('that', 'IN'),
#  ('overall', 'JJ'),
#  ('manufacturing', 'NN'),
#  ('costs', 'NNS'),
#  ('for', 'IN'),
#  ('each', 'DT'),
#  ('vehicle', 'NN'),
#  ('declined', 'VBN'),
#  ('by', 'IN'),
#  ('30', 'CD'),
#  ('%', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('number', 'NN'),
#  ('hours', 'NNS'),
#  ('it', 'PRP'),
#  ('takes', 'VBZ'),
#  ('to', 'TO'),
#  ('build', 'VB'),
#  ('each', 'DT'),
#  ('car', 'NN'),
#  ('fell', 'VBD'),
#  ('too', 'RB'),
#  ('.', '.'),
#  ('That', 'DT'),
#  ('was', 'VBD'),
#  ('enough', 'RB'),
#  ('for', 'IN'),
#  ('skeptical', 'JJ'),
#  ('Tesla', 'NNP'),
#  ('analyst', 'NN'),
#  ('Garrett', 'NNP'),
#  ('Nelson', 'NNP'),
#  ('to', 'TO'),
#  ('change', 'VB'),
#  ('his', 'PRP$'),
#  ('tune', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('The', 'DT'),
#  ('results', 'NNS'),
#  ('look', 'VBP'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('sustainable', 'JJ'),
#  ('going', 'VBG'),
#  ('forward', 'RB'),
#  (',', ','),
#  ("''", "''"),
#  ('the', 'DT'),
#  ('CFRA', 'NNP'),
#  ('Research', 'NNP'),
#  ('analyst', 'NN'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('Nelson', 'NNP'),
#  ('upgraded', 'VBD'),
#  ('his', 'PRP$'),
#  ('recommendation', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('stock', 'NN'),
#  ('after', 'IN'),
#  ('the', 'DT'),
#  ('earnings', 'NNS'),
#  ('report', 'NN'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('said', 'VBD'),
#  ('he', 'PRP'),
#  ('is', 'VBZ'),
#  ('now', 'RB'),
#  ('confident', 'JJ'),
#  ('that', 'IN'),
#  ('Telsa', 'NNP'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('able', 'JJ'),
#  ('to', 'TO'),
#  ('continue', 'VB'),
#  ('to', 'TO'),
#  ('reduce', 'VB'),
#  ('its', 'PRP$'),
#  ('costs', 'NNS'),
#  ('.', '.'),
#  ('Tesla', 'NNP'),
#  ("'s", 'POS'),
#  ('(', '('),
#  ('TSLA', 'NNP'),
#  (')', ')'),
#  ('stock', 'NN'),
#  ('had', 'VBD'),
#  ('lost', 'VBN'),
#  ('about', 'IN'),
#  ('a', 'DT'),
#  ('third', 'JJ'),
#  ('of', 'IN'),
#  ('its', 'PRP$'),
#  ('value', 'NN'),
#  ('since', 'IN'),
#  ('hitting', 'VBG'),
#  ('a', 'DT'),
#  ('record', 'NN'),
#  ('high', 'NN'),
#  ('of', 'IN'),
#  ('$', '$'),
#  ('385', 'CD'),
#  ('a', 'DT'),
#  ('year', 'NN'),
#  ('ago', 'RB'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('stock', 'NN'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('dogged', 'VBN'),
#  ('by', 'IN'),
#  ('concerns', 'NNS'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('company', 'NN'),
#  ('could', 'MD'),
#  ("n't", 'RB'),
#  ('hit', 'VB'),
#  ('production', 'NN'),
#  ('targets', 'NNS'),
#  (',', ','),
#  ('was', 'VBD'),
#  ('burning', 'VBG'),
#  ('through', 'IN'),
#  ('too', 'RB'),
#  ('much', 'JJ'),
#  ('cash', 'NN'),
#  ('and', 'CC'),
#  ('was', 'VBD'),
#  ('facing', 'VBG'),
#  ('looming', 'VBG'),
#  ('debt', 'NN'),
#  ('payments', 'NNS'),
#  ('.', '.'),
#  ('Musk', 'NNP'),
#  ('promised', 'VBD'),
#  ('investors', 'NNS'),
#  ('for', 'IN'),
#  ('months', 'NNS'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('company', 'NN'),
#  ('would', 'MD'),
#  ('be', 'VB'),
#  ('profitable', 'JJ'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('second', 'JJ'),
#  ('half', 'NN'),
#  ('of', 'IN'),
#  ('2018', 'CD'),
#  (',', ','),
#  ('but', 'CC'),
#  ('Wall', 'NNP'),
#  ('Street', 'NNP'),
#  ('had', 'VBD'),
#  ('become', 'VBN'),
#  ('very', 'RB'),
#  ('skeptical', 'JJ'),
#  ('.', '.'),
#  ('``', '``'),
#  ('We', 'PRP'),
#  ('had', 'VBD'),
#  ('our', 'PRP$'),
#  ('doubts', 'NNS'),
#  (',', ','),
#  ("''", "''"),
#  ('Nelson', 'NNP'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('``', '``'),
#  ('This', 'DT'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('company', 'NN'),
#  ('that', 'WDT'),
#  ('has', 'VBZ'),
#  ('a', 'DT'),
#  ('long', 'JJ'),
#  ('history', 'NN'),
#  ('of', 'IN'),
#  ('overpromising', 'VBG'),
#  ('and', 'CC'),
#  ('under', 'IN'),
#  ('delivering', 'VBG'),
#  ('.', '.'),
#  ("''", "''"),
#  ('Tesla', 'NNP'),
#  ("'s", 'POS'),
#  ('profitability', 'NN'),
#  ('comes', 'VBZ'),
#  ('just', 'RB'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('nick', 'NN'),
#  ('of', 'IN'),
#  ('time', 'NN'),
#  ('because', 'IN'),
#  ('$', '$'),
#  ('1.7', 'CD'),
#  ('billion', 'CD'),
#  ('in', 'IN'),
#  ('debt', 'NN'),
#  ('is', 'VBZ'),
#  ('due', 'JJ'),
#  ('by', 'IN'),
#  ('November', 'NNP'),
#  ('of', 'IN'),
#  ('next', 'JJ'),
#  ('year', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('company', 'NN'),
#  ('that', 'WDT'),
#  ('was', 'VBD'),
#  ('burning', 'VBG'),
#  ('through', 'IN'),
#  ('funds', 'NNS'),
#  ('reported', 'VBD'),
#  ('that', 'IN'),
#  ('its', 'PRP$'),
#  ('cash', 'NN'),
#  ('reserves', 'NNS'),
#  ('increased', 'VBN'),
#  ('by', 'IN'),
#  ('$', '$'),
#  ('731', 'CD'),
#  ('million', 'CD'),
#  ('during', 'IN'),
#  ('the', 'DT'),
#  ('quarter', 'NN'),
#  ('.', '.'),
#  ('Musk', 'NNP'),
#  ('told', 'VBD'),
#  ('analysts', 'NNS'),
#  ('that', 'IN'),
#  ('going', 'VBG'),
#  ('forward', 'RB'),
#  (',', ','),
#  ('his', 'PRP$'),
#  ('company', 'NN'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('adding', 'VBG'),
#  ('to', 'TO'),
#  ('its', 'PRP$'),
#  ('cash', 'NN'),
#  ('reserves', 'NNS'),
#  ('instead', 'RB'),
#  ('of', 'IN'),
#  ('burning', 'VBG'),
#  ('through', 'IN'),
#  ('money', 'NN'),
#  ('to', 'TO'),
#  ('boost', 'VB'),
#  ('production', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('I', 'PRP'),
#  ('said', 'VBD'),
#  ('before', 'IN'),
#  ('that', 'DT'),
#  ('we', 'PRP'),
#  ('must', 'MD'),
#  ('prove', 'VB'),
#  ('that', 'IN'),
#  ('Tesla', 'NNP'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('sustainably', 'RB'),
#  ('profitable', 'JJ'),
#  (',', ','),
#  ("''", "''"),
#  ('he', 'PRP'),
#  ('told', 'VBD'),
#  ('analysts', 'NNS'),
#  ('Wednesday', 'NNP'),
#  ('.', '.'),
#  ('``', '``'),
#  ('This', 'DT'),
#  ('quarter', 'NN'),
#  ('was', 'VBD'),
#  ('an', 'DT'),
#  ('important', 'JJ'),
#  ('step', 'NN'),
#  ('towards', 'NNS'),
#  ('that', 'IN'),
#  ('and', 'CC'),
#  ('I', 'PRP'),
#  ("'m", 'VBP'),
#  ('incredibly', 'RB'),
#  ('excited', 'VBN'),
#  ('about', 'IN'),
#  ('what', 'WP'),
#  ('lies', 'VBZ'),
#  ('ahead', 'RB'),
#  ('.', '.'),
#  ("''", "''"),
#  ('Tesla', 'NNP'),
#  ('&', 'CC'),
#  ('#', '#'),
#  ('39', 'CD'),
#  (';', ':'),
#  ('s', 'JJ'),
#  ('Model', 'NNP'),
#  ('3', 'CD'),
#  ('Performance', 'NNP'),
#  ('is', 'VBZ'),
#  ('an', 'DT'),
#  ('amazing', 'JJ'),
#  ('car', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('it', 'PRP'),
#  ('&', 'CC'),
#  ('#', '#'),
#  ('39', 'CD'),
#  (';', ':'),
#  ('s', 'NN'),
#  ('got', 'VBD'),
#  ('some', 'DT'),
#  ('issues', 'NNS'),
#  ('Tesla', 'NNP'),
#  ("'s", 'POS'),
#  ('Model', 'NNP'),
#  ('3', 'CD'),
#  ('Performance', 'NNP'),
#  ('is', 'VBZ'),
#  ('an', 'DT'),
#  ('amazing', 'JJ'),
#  ('car', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('it', 'PRP'),
#  ("'s", 'VBZ'),
#  ('got', 'VBD'),
#  ('some', 'DT'),
#  ('issues', 'NNS'),
#  ('Gene', 'NNP'),
#  ('Munster', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('leading', 'VBG'),
#  ('tech', 'JJ'),
#  ('analyst', 'NN'),
#  ('with', 'IN'),
#  ('Loup', 'NNP'),
#  ('Ventures', 'NNP'),
#  (',', ','),
#  ('said', 'VBD'),
#  ('its', 'PRP$'),
#  ('good', 'JJ'),
#  ('to', 'TO'),
#  ('see', 'VB'),
#  ('the', 'DT'),
#  ('focus', 'NN'),
#  ('return', 'NN'),
#  ('to', 'TO'),
#  ('Tesla', 'NNP'),
#  ("'s", 'POS'),
#  ('business', 'NN'),
#  ('and', 'CC'),
#  ('not', 'RB'),
#  ('on', 'IN'),
#  ('Musk', 'NNP'),
#  ("'s", 'POS'),
#  ('erratic', 'JJ'),
#  ('behavior', 'NN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('August', 'NNP'),
#  (',', ','),
#  ('Musk', 'NNP'),
#  ('tweeted', 'VBD'),
#  ('a', 'DT'),
#  ('plan', 'NN'),
#  ('to', 'TO'),
#  ('take', 'VB'),
#  ('the', 'DT'),
#  ('company', 'NN'),
#  ('private', 'JJ'),
#  (',', ','),
#  ('only', 'RB'),
#  ('to', 'TO'),
#  ('drop', 'VB'),
#  ('the', 'DT'),
#  ('plan', 'NN'),
#  ('less', 'JJR'),
#  ('than', 'IN'),
#  ('three', 'CD'),
#  ('weeks', 'NNS'),
#  ('later', 'RB'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Securities', 'NNPS'),
#  ('and', 'CC'),
#  ('Exchange', 'NNP'),
#  ('Commission', 'NNP'),
#  ('fined', 'VBD'),
#  ('him', 'PRP'),
#  ('$', '$'),
#  ('20', 'CD'),
#  ('million', 'CD'),
#  ('and', 'CC'),
#  ('required', 'VBD'),
#  ('him', 'PRP'),
#  ('to', 'TO'),
#  ('give', 'VB'),
#  ('up', 'RP'),
#  ('the', 'DT'),
#  ('chairman', 'NN'),
#  ('post', 'NN'),
#  ('because', 'IN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('false', 'JJ'),
#  ('statement', 'NN'),
#  ('that', 'IN'),
#  ('he', 'PRP'),
#  ('had', 'VBD'),
#  ('``', '``'),
#  ('funding', 'NN'),
#  ('secured', 'JJ'),
#  ("''", "''"),
#  ('for', 'IN'),
#  ('such', 'PDT'),
#  ('a', 'DT'),
#  ('move', 'NN'),
#  ('when', 'WRB'),
#  ('he', 'PRP'),
#  ('did', 'VBD'),
#  ('not', 'RB'),
#  ('.', '.'),
#  ('Musk', 'NNP'),
#  ('also', 'RB'),
#  ('drank', 'VBD'),
#  ('alcohol', 'NN'),
#  ('and', 'CC'),
#  ('smoked', 'VBD'),
#  ('pot', 'NN'),
#  ('on', 'IN'),
#  ('a', 'DT'),
#  ('podcast', 'NN'),
#  (',', ','),
#  ('maligned', 'VBD'),
#  ('a', 'DT'),
#  ('man', 'NN'),
#  ('who', 'WP'),
#  ('helped', 'VBD'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('rescue', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('Thai', 'NNP'),
#  ('soccer', 'NN'),
#  ('team', 'NN'),
#  ('trapped', 'VBN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('cave', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('lambasted', 'VBD'),
#  ('analysts', 'NNS'),
#  ('on', 'IN'),
#  ('a', 'DT'),
#  ('conference', 'NN'),
#  ('call', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('behavior', 'NN'),
#  ('spooked', 'VBD'),
#  ('many', 'JJ'),
#  ('investors', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('Munster', 'NNP'),
#  ('said', 'VBD'),
#  ('he', 'PRP'),
#  ("'s", 'VBZ'),
#  ('not', 'RB'),
#  ('sure', 'JJ'),
#  ('the', 'DT'),
#  ('great', 'JJ'),
#  ('quarter', 'NN'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('enough', 'RB'),
#  ('by', 'IN'),
#  ('itself', 'PRP'),
#  ('to', 'TO'),
#  ('convince', 'VB'),
#  ('everyone', 'NN'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('company', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('safe', 'JJ'),
#  ('investment', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('I', 'PRP'),
#  ('think', 'VBP'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('important', 'JJ'),
#  ('step', 'NN'),
#  ('they', 'PRP'),
#  ("'ve", 'VBP'),
#  ('taken', 'VBN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('we', 'PRP'),
#  ("'re", 'VBP'),
#  ('not', 'RB'),
#  ('out', 'IN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('woods', 'NNS'),
#  ('yet', 'RB'),
#  (',', ','),
#  ("''", "''"),
#  ('Munster', 'NNP'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('Morgan', 'NNP'),
#  ('Stanley', 'NNP'),
#  ('auto', 'NN'),
#  ('analyst', 'NN'),
#  ('Adam', 'NNP'),
#  ('Jonas', 'NNP'),
#  (',', ','),
#  ('who', 'WP'),
#  ('still', 'RB'),
#  ('has', 'VBZ'),
#  ('a', 'DT'),
#  ('neutral', 'JJ'),
#  ('rating', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('stock', 'NN'),
#  (',', ','),
#  ('said', 'VBD'),
#  ('that', 'IN'),
#  ('he', 'PRP'),
#  ('and', 'CC'),
#  ('other', 'JJ'),
#  ('investors', 'NNS'),
#  ('will', 'MD'),
#  ('want', 'VB'),
#  ('to', 'TO'),
#  ('see', 'VB'),
#  ('Tesla', 'NNP'),
#  ('repeat', 'VB'),
#  ('this', 'DT'),
#  ('performance', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('fourth', 'JJ'),
#  ('quarter', 'NN'),
#  ('and', 'CC'),
#  ('beyond', 'IN'),
#  ('before', 'IN'),
#  ('the', 'DT'),
#  ('stock', 'NN'),
#  ('can', 'MD'),
#  ('regain', 'VB'),
#  ('some', 'DT'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('ground', 'NN'),
#  ('it', 'PRP'),
#  ('lost', 'VBD'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('last', 'JJ'),
#  ('year', 'NN'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('even', 'RB'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('Tesla', 'NNP'),
#  ("'s", 'POS'),
#  ('harsher', 'NN'),
#  ('critics', 'NNS'),
#  ('has', 'VBZ'),
#  ('said', 'VBD'),
#  ('he', 'PRP'),
#  ('expects', 'VBZ'),
#  ('that', 'IN'),
#  ('Tesla', 'NNP'),
#  ("'s", 'POS'),
#  ('stock', 'NN'),
#  ('will', 'MD'),
#  ('now', 'RB'),
#  ('start', 'VB'),
#  ('to', 'TO'),
#  ('regain', 'VB'),
#  ('lost', 'VBN'),
#  ('ground', 'NN'),
#  ('.', '.'),
#  ('John', 'NNP'),
#  ('Thompson', 'NNP'),
#  ('CEO', 'NNP'),
#  ('of', 'IN'),
#  ('hedge', 'NN'),
#  ('fund', 'NN'),
#  ('Vilas', 'NNP'),
#  ('Capital', 'NNP'),
#  ('Management', 'NNP'),
#  (',', ','),
#  ('said', 'VBD'),
#  ('he', 'PRP'),
#  ('has', 'VBZ'),
#  ('now', 'RB'),
#  ('closed', 'VBN'),
#  ('his', 'PRP$'),
#  ('short', 'JJ'),
#  ('positions', 'NNS'),
#  ('which', 'WDT'),
#  ('bet', 'VBP'),
#  ('on', 'IN'),
#  ('a', 'DT'),
#  ('continued', 'JJ'),
#  ('decline', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('price', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('stock', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('My', 'PRP$'),
#  ('estimates', 'NNS'),
#  ('of', 'IN'),
#  ('their', 'PRP$'),
#  ('demise', 'NN'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('greatly', 'RB'),
#  ('exaggerated', 'JJ'),
#  (',', ','),
#  ("''", "''"),
#  ('he', 'PRP'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('``', '``'),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('long', 'JJ'),
#  ('run', 'NN'),
#  ('it', 'PRP'),
#  ('does', 'VBZ'),
#  ("n't", 'RB'),
#  ('change', 'VB'),
#  ('anything', 'NN'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('short', 'JJ'),
#  ('run', 'NN'),
#  ('they', 'PRP'),
#  ("'ve", 'VBP'),
#  ('pulled', 'VBN'),
#  ('the', 'DT'),
#  ('rabbit', 'NN'),
#  ('out', 'IN'),
#  ('the', 'DT'),
#  ('hat', 'NN'),
#  ('.', '.'),
#  ("''", "''")]

# %%
tree1 = nltk.Tree('NP',['Alick'])
print(tree1)
tree2 = nltk.Tree('N',['Alick','Rabbit'])
print(tree2)
tree3 = nltk.Tree('S',[tree1,tree2])
print(tree3.label())
tree3.draw()
# Out:
# (NP Alick)
# (N Alick Rabbit)
# S

# %%
NER = ne_chunk(nltk.pos_tag(word_tokenize(strEx)), binary=False)

# %%
type(NER)
# Out:
# nltk.tree.Tree

# %%
print(NER)
# Out:
# (S
#   (GPE New/NNP York/NNP)
#   (/(
#   (ORGANIZATION CNN/NNP)
#   Business/NNP
#   )/)
#   Over/IN
#   the/DT
#   last/JJ
#   10/CD
#   years/NNS
#   (PERSON Tesla/NNP CEO/NNP Elon/NNP Musk/NNP)
#   has/VBZ
#   been/VBN
#   promising/VBG
#   (FACILITY Wall/NNP Street/NNP)
#   that/IN
#   his/PRP$
#   electric/JJ
#   car/NN
#   company/NN
#   would/MD
#   eventually/RB
#   make/VB
#   money/NN
#   ./.
#   Wednesday/NNP
#   he/PRP
#   finally/RB
#   made/VBD
#   good/JJ
#   on/IN
#   that/DT
#   promise/NN
#   ./.
#   (PERSON Shares/NNS)
#   closed/VBD
#   up/RB
#   9/CD
#   %/NN
#   Thursday/NNP
#   after/IN
#   the/DT
#   company/NN
#   posted/VBD
#   its/PRP$
#   best/JJS
#   quarter/NN
#   ever/RB
#   the/DT
#   previous/JJ
#   evening/NN
#   ./.
#   The/DT
#   big/JJ
#   question/NN
#   now/RB
#   is/VBZ
#   whether/IN
#   the/DT
#   company/NN
#   can/MD
#   remain/VB
#   profitable/JJ
#   ./.
#   (PERSON Tesla/NNP)
#   scores/VBZ
#   a/DT
#   profit/NN
#   ,/,
#   and/CC
#   (PERSON Elon/NNP Musk/NNP)
#   keeps/VBZ
#   a/DT
#   promise/NN
#   (PERSON Tesla/NNP)
#   scores/VBZ
#   a/DT
#   profit/NN
#   ,/,
#   and/CC
#   (PERSON Elon/NNP Musk/NNP)
#   keeps/VBZ
#   a/DT
#   promise/NN
#   (PERSON Tesla/NNP)
#   's/POS
#   strong/JJ
#   report/NN
#   showed/VBD
#   that/IN
#   overall/JJ
#   manufacturing/NN
#   costs/NNS
#   for/IN
#   each/DT
#   vehicle/NN
#   declined/VBN
#   by/IN
#   30/CD
#   %/NN
#   ./.
#   The/DT
#   number/NN
#   hours/NNS
#   it/PRP
#   takes/VBZ
#   to/TO
#   build/VB
#   each/DT
#   car/NN
#   fell/VBD
#   too/RB
#   ./.
#   That/DT
#   was/VBD
#   enough/RB
#   for/IN
#   skeptical/JJ
#   Tesla/NNP
#   analyst/NN
#   (PERSON Garrett/NNP Nelson/NNP)
#   to/TO
#   change/VB
#   his/PRP$
#   tune/NN
#   ./.
#   ``/``
#   The/DT
#   results/NNS
#   look/VBP
#   to/TO
#   be/VB
#   sustainable/JJ
#   going/VBG
#   forward/RB
#   ,/,
#   ''/''
#   the/DT
#   (ORGANIZATION CFRA/NNP)
#   Research/NNP
#   analyst/NN
#   said/VBD
#   ./.
#   (PERSON Nelson/NNP)
#   upgraded/VBD
#   his/PRP$
#   recommendation/NN
#   on/IN
#   the/DT
#   stock/NN
#   after/IN
#   the/DT
#   earnings/NNS
#   report/NN
#   ./.
#   He/PRP
#   said/VBD
#   he/PRP
#   is/VBZ
#   now/RB
#   confident/JJ
#   that/IN
#   (PERSON Telsa/NNP)
#   will/MD
#   be/VB
#   able/JJ
#   to/TO
#   continue/VB
#   to/TO
#   reduce/VB
#   its/PRP$
#   costs/NNS
#   ./.
#   (PERSON Tesla/NNP)
#   's/POS
#   (/(
#   (ORGANIZATION TSLA/NNP)
#   )/)
#   stock/NN
#   had/VBD
#   lost/VBN
#   about/IN
#   a/DT
#   third/JJ
#   of/IN
#   its/PRP$
#   value/NN
#   since/IN
#   hitting/VBG
#   a/DT
#   record/NN
#   high/NN
#   of/IN
#   $/$
#   385/CD
#   a/DT
#   year/NN
#   ago/RB
#   ./.
#   The/DT
#   stock/NN
#   has/VBZ
#   been/VBN
#   dogged/VBN
#   by/IN
#   concerns/NNS
#   that/IN
#   the/DT
#   company/NN
#   could/MD
#   n't/RB
#   hit/VB
#   production/NN
#   targets/NNS
#   ,/,
#   was/VBD
#   burning/VBG
#   through/IN
#   too/RB
#   much/JJ
#   cash/NN
#   and/CC
#   was/VBD
#   facing/VBG
#   looming/VBG
#   debt/NN
#   payments/NNS
#   ./.
#   (PERSON Musk/NNP)
#   promised/VBD
#   investors/NNS
#   for/IN
#   months/NNS
#   that/IN
#   the/DT
#   company/NN
#   would/MD
#   be/VB
#   profitable/JJ
#   in/IN
#   the/DT
#   second/JJ
#   half/NN
#   of/IN
#   2018/CD
#   ,/,
#   but/CC
#   (PERSON Wall/NNP Street/NNP)
#   had/VBD
#   become/VBN
#   very/RB
#   skeptical/JJ
#   ./.
#   ``/``
#   We/PRP
#   had/VBD
#   our/PRP$
#   doubts/NNS
#   ,/,
#   ''/''
#   (PERSON Nelson/NNP)
#   said/VBD
#   ./.
#   ``/``
#   This/DT
#   is/VBZ
#   a/DT
#   company/NN
#   that/WDT
#   has/VBZ
#   a/DT
#   long/JJ
#   history/NN
#   of/IN
#   overpromising/VBG
#   and/CC
#   under/IN
#   delivering/VBG
#   ./.
#   ''/''
#   (PERSON Tesla/NNP)
#   's/POS
#   profitability/NN
#   comes/VBZ
#   just/RB
#   in/IN
#   the/DT
#   nick/NN
#   of/IN
#   time/NN
#   because/IN
#   $/$
#   1.7/CD
#   billion/CD
#   in/IN
#   debt/NN
#   is/VBZ
#   due/JJ
#   by/IN
#   November/NNP
#   of/IN
#   next/JJ
#   year/NN
#   ./.
#   The/DT
#   company/NN
#   that/WDT
#   was/VBD
#   burning/VBG
#   through/IN
#   funds/NNS
#   reported/VBD
#   that/IN
#   its/PRP$
#   cash/NN
#   reserves/NNS
#   increased/VBN
#   by/IN
#   $/$
#   731/CD
#   million/CD
#   during/IN
#   the/DT
#   quarter/NN
#   ./.
#   (PERSON Musk/NNP)
#   told/VBD
#   analysts/NNS
#   that/IN
#   going/VBG
#   forward/RB
#   ,/,
#   his/PRP$
#   company/NN
#   will/MD
#   be/VB
#   adding/VBG
#   to/TO
#   its/PRP$
#   cash/NN
#   reserves/NNS
#   instead/RB
#   of/IN
#   burning/VBG
#   through/IN
#   money/NN
#   to/TO
#   boost/VB
#   production/NN
#   ./.
#   ``/``
#   I/PRP
#   said/VBD
#   before/IN
#   that/DT
#   we/PRP
#   must/MD
#   prove/VB
#   that/IN
#   (PERSON Tesla/NNP)
#   can/MD
#   be/VB
#   sustainably/RB
#   profitable/JJ
#   ,/,
#   ''/''
#   he/PRP
#   told/VBD
#   analysts/NNS
#   Wednesday/NNP
#   ./.
#   ``/``
#   This/DT
#   quarter/NN
#   was/VBD
#   an/DT
#   important/JJ
#   step/NN
#   towards/NNS
#   that/IN
#   and/CC
#   I/PRP
#   'm/VBP
#   incredibly/RB
#   excited/VBN
#   about/IN
#   what/WP
#   lies/VBZ
#   ahead/RB
#   ./.
#   ''/''
#   Tesla/NNP
#   &/CC
#   #/#
#   39/CD
#   ;/:
#   s/JJ
#   Model/NNP
#   3/CD
#   Performance/NNP
#   is/VBZ
#   an/DT
#   amazing/JJ
#   car/NN
#   ,/,
#   but/CC
#   it/PRP
#   &/CC
#   #/#
#   39/CD
#   ;/:
#   s/NN
#   got/VBD
#   some/DT
#   issues/NNS
#   (PERSON Tesla/NNP)
#   's/POS
#   Model/NNP
#   3/CD
#   Performance/NNP
#   is/VBZ
#   an/DT
#   amazing/JJ
#   car/NN
#   ,/,
#   but/CC
#   it/PRP
#   's/VBZ
#   got/VBD
#   some/DT
#   issues/NNS
#   (PERSON Gene/NNP Munster/NNP)
#   ,/,
#   a/DT
#   leading/VBG
#   tech/JJ
#   analyst/NN
#   with/IN
#   (PERSON Loup/NNP Ventures/NNP)
#   ,/,
#   said/VBD
#   its/PRP$
#   good/JJ
#   to/TO
#   see/VB
#   the/DT
#   focus/NN
#   return/NN
#   to/TO
#   (PERSON Tesla/NNP)
#   's/POS
#   business/NN
#   and/CC
#   not/RB
#   on/IN
#   (PERSON Musk/NNP)
#   's/POS
#   erratic/JJ
#   behavior/NN
#   ./.
#   In/IN
#   (GPE August/NNP)
#   ,/,
#   (PERSON Musk/NNP)
#   tweeted/VBD
#   a/DT
#   plan/NN
#   to/TO
#   take/VB
#   the/DT
#   company/NN
#   private/JJ
#   ,/,
#   only/RB
#   to/TO
#   drop/VB
#   the/DT
#   plan/NN
#   less/JJR
#   than/IN
#   three/CD
#   weeks/NNS
#   later/RB
#   ./.
#   The/DT
#   (ORGANIZATION Securities/NNPS)
#   and/CC
#   (ORGANIZATION Exchange/NNP Commission/NNP)
#   fined/VBD
#   him/PRP
#   $/$
#   20/CD
#   million/CD
#   and/CC
#   required/VBD
#   him/PRP
#   to/TO
#   give/VB
#   up/RP
#   the/DT
#   chairman/NN
#   post/NN
#   because/IN
#   of/IN
#   a/DT
#   false/JJ
#   statement/NN
#   that/IN
#   he/PRP
#   had/VBD
#   ``/``
#   funding/NN
#   secured/JJ
#   ''/''
#   for/IN
#   such/PDT
#   a/DT
#   move/NN
#   when/WRB
#   he/PRP
#   did/VBD
#   not/RB
#   ./.
#   (PERSON Musk/NNP)
#   also/RB
#   drank/VBD
#   alcohol/NN
#   and/CC
#   smoked/VBD
#   pot/NN
#   on/IN
#   a/DT
#   podcast/NN
#   ,/,
#   maligned/VBD
#   a/DT
#   man/NN
#   who/WP
#   helped/VBD
#   in/IN
#   the/DT
#   rescue/NN
#   of/IN
#   a/DT
#   (GPE Thai/NNP)
#   soccer/NN
#   team/NN
#   trapped/VBN
#   in/IN
#   a/DT
#   cave/NN
#   ,/,
#   and/CC
#   lambasted/VBD
#   analysts/NNS
#   on/IN
#   a/DT
#   conference/NN
#   call/NN
#   ./.
#   The/DT
#   behavior/NN
#   spooked/VBD
#   many/JJ
#   investors/NNS
#   ,/,
#   and/CC
#   (PERSON Munster/NNP)
#   said/VBD
#   he/PRP
#   's/VBZ
#   not/RB
#   sure/JJ
#   the/DT
#   great/JJ
#   quarter/NN
#   will/MD
#   be/VB
#   enough/RB
#   by/IN
#   itself/PRP
#   to/TO
#   convince/VB
#   everyone/NN
#   that/IN
#   the/DT
#   company/NN
#   is/VBZ
#   a/DT
#   safe/JJ
#   investment/NN
#   ./.
#   ``/``
#   I/PRP
#   think/VBP
#   it/PRP
#   was/VBD
#   the/DT
#   important/JJ
#   step/NN
#   they/PRP
#   've/VBP
#   taken/VBN
#   ,/,
#   but/CC
#   we/PRP
#   're/VBP
#   not/RB
#   out/IN
#   of/IN
#   the/DT
#   woods/NNS
#   yet/RB
#   ,/,
#   ''/''
#   (PERSON Munster/NNP)
#   said/VBD
#   ./.
#   (PERSON Morgan/NNP Stanley/NNP)
#   auto/NN
#   analyst/NN
#   (PERSON Adam/NNP Jonas/NNP)
#   ,/,
#   who/WP
#   still/RB
#   has/VBZ
#   a/DT
#   neutral/JJ
#   rating/NN
#   on/IN
#   the/DT
#   stock/NN
#   ,/,
#   said/VBD
#   that/IN
#   he/PRP
#   and/CC
#   other/JJ
#   investors/NNS
#   will/MD
#   want/VB
#   to/TO
#   see/VB
#   (PERSON Tesla/NNP)
#   repeat/VB
#   this/DT
#   performance/NN
#   in/IN
#   the/DT
#   fourth/JJ
#   quarter/NN
#   and/CC
#   beyond/IN
#   before/IN
#   the/DT
#   stock/NN
#   can/MD
#   regain/VB
#   some/DT
#   of/IN
#   the/DT
#   ground/NN
#   it/PRP
#   lost/VBD
#   in/IN
#   the/DT
#   last/JJ
#   year/NN
#   ./.
#   But/CC
#   even/RB
#   one/CD
#   of/IN
#   (GPE Tesla/NNP)
#   's/POS
#   harsher/NN
#   critics/NNS
#   has/VBZ
#   said/VBD
#   he/PRP
#   expects/VBZ
#   that/IN
#   (PERSON Tesla/NNP)
#   's/POS
#   stock/NN
#   will/MD
#   now/RB
#   start/VB
#   to/TO
#   regain/VB
#   lost/VBN
#   ground/NN
#   ./.
#   (PERSON John/NNP Thompson/NNP)
#   CEO/NNP
#   of/IN
#   hedge/NN
#   fund/NN
#   (PERSON Vilas/NNP Capital/NNP Management/NNP)
#   ,/,
#   said/VBD
#   he/PRP
#   has/VBZ
#   now/RB
#   closed/VBN
#   his/PRP$
#   short/JJ
#   positions/NNS
#   which/WDT
#   bet/VBP
#   on/IN
#   a/DT
#   continued/JJ
#   decline/NN
#   in/IN
#   the/DT
#   price/NN
#   of/IN
#   the/DT
#   stock/NN
#   ./.
#   ``/``
#   My/PRP$
#   estimates/NNS
#   of/IN
#   their/PRP$
#   demise/NN
#   have/VBP
#   been/VBN
#   greatly/RB
#   exaggerated/JJ
#   ,/,
#   ''/''
#   he/PRP
#   said/VBD
#   ./.
#   ``/``
#   In/IN
#   the/DT
#   long/JJ
#   run/NN
#   it/PRP
#   does/VBZ
#   n't/RB
#   change/VB
#   anything/NN
#   ./.
#   But/CC
#   in/IN
#   the/DT
#   short/JJ
#   run/NN
#   they/PRP
#   've/VBP
#   pulled/VBN
#   the/DT
#   rabbit/NN
#   out/IN
#   the/DT
#   hat/NN
#   ./.
#   ''/'')

# %%
def get_continuous_chunks(text, label):
    chunked = ne_chunk(pos_tag(word_tokenize(text)))
    prev = None
    continuous_chunk = []
    current_chunk = []

    for subtree in chunked:
        if type(subtree) == Tree and subtree.label() == label:
            current_chunk.append(" ".join([token for token, pos in subtree.leaves()]))
        elif current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue

    return continuous_chunk

# %%
get_continuous_chunks(strEx, 'PERSON')
# Out:
# ['Tesla CEO Elon Musk',
#  'Shares',
#  'Tesla',
#  'Elon Musk',
#  'Tesla Elon Musk',
#  'Tesla Garrett Nelson',
#  'Nelson',
#  'Telsa',
#  'Tesla Musk',
#  'Wall Street',
#  'Nelson Tesla',
#  'Musk',
#  'Tesla Tesla',
#  'Gene Munster',
#  'Loup Ventures',
#  'Tesla Musk Musk',
#  'Musk Munster',
#  'Munster',
#  'Morgan Stanley',
#  'Adam Jonas',
#  'Tesla Tesla John Thompson',
#  'Vilas Capital Management']

# %%
get_continuous_chunks(strEx, 'ORGANIZATION')
# Out:
# ['CNN', 'CFRA', 'TSLA', 'Securities', 'Exchange Commission']
